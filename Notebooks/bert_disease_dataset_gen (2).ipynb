# %%
import pandas as pd
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/dataset.csv')
df
# Out:
#                                       Disease             Symptom_1  \
# 0                            Fungal infection               itching
# 1                            Fungal infection             skin_rash
# 2                            Fungal infection               itching
# 3                            Fungal infection               itching
# 4                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
df.shape
# Out:
# (4920, 18)

# %%
df.isnull().sum()
# Out:
# Disease          0
# Symptom_1        0
# Symptom_2        0
# Symptom_3        0
# Symptom_4      348
# Symptom_5     1206
# Symptom_6     1986
# Symptom_7     2652
# Symptom_8     2976
# Symptom_9     3228
# Symptom_10    3408
# Symptom_11    3726
# Symptom_12    4176
# Symptom_13    4416
# Symptom_14    4614
# Symptom_15    4680
# Symptom_16    4728
# Symptom_17    4848
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(4616)

# %%
df[df.duplicated()]
# Out:
#                                       Disease             Symptom_1  \
# 5                            Fungal infection             skin_rash
# 6                            Fungal infection               itching
# 7                            Fungal infection               itching
# 8                            Fungal infection               itching
# 9                            Fungal infection               itching
# ...                                       ...                   ...
# 4915  (vertigo) Paroymsal  Positional Vertigo              vomiting
# 4916                                     Acne             skin_rash
# 4917                  Urinary tract infection   burning_micturition
# 4918                                Psoriasis             skin_rash
# 4919                                 Impetigo             skin_rash
#
#                   Symptom_2              Symptom_3                  Symptom_4  \
# ...

# %%
df_new=df[~df.duplicated()]
df_new
# Out:
#               Disease    Symptom_1              Symptom_2  \
# 0    Fungal infection      itching              skin_rash
# 1    Fungal infection    skin_rash   nodal_skin_eruptions
# 2    Fungal infection      itching   nodal_skin_eruptions
# 3    Fungal infection      itching              skin_rash
# 4    Fungal infection      itching              skin_rash
# ..                ...          ...                    ...
# 402          Impetigo   high_fever                blister
# 403          Impetigo    skin_rash                blister
# 405          Impetigo    skin_rash             high_fever
# 406          Impetigo    skin_rash             high_fever
# 407          Impetigo    skin_rash             high_fever
#
#                  Symptom_3              Symptom_4 Symptom_5 Symptom_6  \
# 0     nodal_skin_eruptions    dischromic _patches       NaN       NaN
# 1      dischromic _patches                    NaN       NaN       NaN
# ...

# %%
df.Disease.value_counts()
# Out:
# Disease
# Fungal infection                           120
# Allergy                                    120
# GERD                                       120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# AIDS                                       120
# Diabetes                                   120
# Gastroenteritis                            120
# Bronchial Asthma                           120
# Hypertension                               120
# Migraine                                   120
# Cervical spondylosis                       120
# Paralysis (brain hemorrhage)               120
# Jaundice                                   120
# Malaria                                    120
# Chicken pox                                120
# Dengue                                     120
# Typhoid                                    120
# hepatitis A                                120
# ...

# %%
symptom_cols = [col for col in df.columns if col.startswith("Symptom")]

# %%
df['text'] = df[symptom_cols].apply(lambda row: ', '.join(row.dropna().astype(str)), axis=1)

# %%
def preprocess_symptom_text(text):
    return text.replace("_", " ")

# %%
df['text']=df['text'].apply(preprocess_symptom_text)

# %%
df.sample(5)
# Out:
#                            Disease    Symptom_1            Symptom_2  \
# 2941                Varicose veins      fatigue               cramps
# 4318  Paralysis (brain hemorrhage)     vomiting             headache
# 1158                  Hypoglycemia     vomiting              fatigue
# 2421                          Acne    skin_rash   pus_filled_pimples
# 4655                   Hepatitis D   joint_pain             vomiting
#
#                        Symptom_3           Symptom_4      Symptom_5  \
# 2941                    bruising             obesity   swollen_legs
# 4318   weakness_of_one_body_side   altered_sensorium            NaN
# 1158                     anxiety            sweating       headache
# 2421                  blackheads            scurring            NaN
# 4655                     fatigue      yellowish_skin     dark_urine
#
#                           Symptom_6                 Symptom_7  \
# 2941          swollen_blood_vessels   prominent_veins_on_calf
# ...

# %%
symptom_cols
# Out:
# ['Symptom_1',
#  'Symptom_2',
#  'Symptom_3',
#  'Symptom_4',
#  'Symptom_5',
#  'Symptom_6',
#  'Symptom_7',
#  'Symptom_8',
#  'Symptom_9',
#  'Symptom_10',
#  'Symptom_11',
#  'Symptom_12',
#  'Symptom_13',
#  'Symptom_14',
#  'Symptom_15',
#  'Symptom_16',
#  'Symptom_17']

# %%
df_unique = df[['text', 'Disease']]
df_unique
# Out:
#                                                    text  \
# 0     itching,  skin rash,  nodal skin eruptions,  d...
# 1      skin rash,  nodal skin eruptions,  dischromic...
# 2     itching,  nodal skin eruptions,  dischromic  p...
# 3             itching,  skin rash,  dischromic  patches
# 4            itching,  skin rash,  nodal skin eruptions
# ...                                                 ...
# 4915   vomiting,  headache,  nausea,  spinning movem...
# 4916   skin rash,  pus filled pimples,  blackheads, ...
# 4917   burning micturition,  bladder discomfort,  fo...
# 4918   skin rash,  joint pain,  skin peeling,  silve...
# 4919   skin rash,  high fever,  blister,  red sore a...
#
#                                       Disease
# 0                            Fungal infection
# 1                            Fungal infection
# 2                            Fungal infection
# 3                            Fungal infection
# 4                            Fungal infection
# ...

# %%
# Save to CSV
df_unique.to_csv("/content/drive/MyDrive/augmented_symptom_disease_dataset.csv", index=False)

# (Optional) Save to Excel
# df_expanded.to_excel("augmented_symptom_disease_dataset.xlsx", index=False)

# %%
import re
max_ln=0
s=[]
def max_len(txt):
  words = re.findall(r'\b\w+\b', txt)
  global max_ln
  global s
  if max_ln<len(words):
    max_ln=len(words)
    s=words

df_unique['text'].apply(max_len)
print(max_ln,s)
# Out:
# 30 ['continuous', 'sneezing', 'chills', 'fatigue', 'cough', 'high', 'fever', 'headache', 'swelled', 'lymph', 'nodes', 'malaise', 'phlegm', 'throat', 'irritation', 'redness', 'of', 'eyes', 'sinus', 'pressure', 'runny', 'nose', 'congestion', 'chest', 'pain', 'loss', 'of', 'smell', 'muscle', 'pain']
